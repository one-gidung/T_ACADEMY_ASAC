# %%
# 아래는 colab에서 설치할 경우에 한해서임!!!!!
# 이 셀의 코드는 colab에서 할 때에 한해서임!!!!!!-----

# !apt-get -qq install -y graphviz && pip install -q pydot

# %%
################## DT 잘 안돌아요;;;;; ######
#### 본인 윈도우기반의 노트북에서 하실 때 
# 1. graphviz 홈페이지에 가서 os에 맞는 파일을 다운로드
# 2. 윈도우의 경우 시스템 변수 path : ~~~graphviz/bindot.exe경로
# 3. 위도우의 경우 사용자 변수 path : ~graphviz/bin 경로지정
# 4. pydotplus 패키지를 설치 : conda install -c anaconda pydotplus
######################################

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
dt_clf = DecisionTreeClassifier()
iris_data= load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris_data.data, iris_data.target, test_size=0.2)

# %%
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import export_graphviz

# %%
export_graphviz(dt_clf,  # <- DT의 학습된 모델
                out_file="tree.dot", 
                class_names=iris_data.target_names,
                # target/label 이름 :정답지
               feature_names=iris_data.feature_names,
                # 특징 이름, 컬럼명 
                impurity=True, filled=True)
# ---> 단순히 외부로 .dot 형식으로 그래프를 출력...

# %%
import export_graphviz
from six import StringIO # <- scikitlearn 1.X
from IPython.display import Image
import pydotplus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 import export_graphviz
#       2 from six import StringIO # <- scikitlearn 1.X
#       3 from IPython.display import Image
#
# ModuleNotFoundError: No module named 'export_graphviz'

# %%
dot_data = StringIO()
export_graphviz(dt_clf, out_file=dot_data, class_names=iris_data.target_names,
               feature_names=iris_data.feature_names, impurity=True, filled=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 dot_data = StringIO()
#       2 export_graphviz(dt_clf, out_file=dot_data, class_names=iris_data.target_names,
#       3                feature_names=iris_data.feature_names, impurity=True, filled=True)
#       4 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#
# NameError: name 'StringIO' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)
