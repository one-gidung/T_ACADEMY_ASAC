# %%
from models import Yolov4

# %%
from utils import DataGenerator, read_annotation_lines
from models import Yolov4

# %%
train_lines, val_lines = read_annotation_lines('./dataset2/txt/anno.txt', test_size=0.1)

FOLDER_PATH = './dataset2/img'
class_name_path = './class_names/classes2.txt'
data_gen_train = DataGenerator( train_lines, class_name_path, FOLDER_PATH )
data_gen_val = DataGenerator( val_lines, class_name_path, FOLDER_PATH )

# %%
model = Yolov4(class_name_path=class_name_path )
model.fit( data_gen_train, initial_epoch=0, epochs=10, val_data_gen=data_gen_val )
# Out:
# nms iou: 0.413 score: 0.3
# Epoch 1/10
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 3/3 [==============================] - 181s 39s/step - loss: 119367.6562 - val_loss: 116914.7578
# Epoch 2/10
# 3/3 [==============================] - 82s 35s/step - loss: 59313.4062 - val_loss: 111298.0234
# Epoch 3/10
# 3/3 [==============================] - 82s 25s/step - loss: 31497.0234 - val_loss: 104441.5859
# Epoch 4/10
# 3/3 [==============================] - 81s 34s/step - loss: 15017.2666 - val_loss: 97539.2500
# Epoch 5/10
# 3/3 [==============================] - 233s 15s/step - loss: 8863.6162 - val_loss: 88190.5078
# Epoch 6/10
# 3/3 [==============================] - 32s 10s/step - loss: 4850.7598 - val_loss: 77391.8828
# Epoch 7/10
# 3/3 [==============================] - 32s 9s/step - loss: 3016.5359 - val_loss: 67149.0156
# Epoch 8/10
# 3/3 [==============================] - 32s 9s/step - loss: 2097.9668 - val_loss: 58299.5664
# Epoch 9/10
# 3/3 [==============================] - 32s 10s/step - loss: 1495.8871 - val_loss: 50028.4258
# Epoch 10/10
# 3/3 [==============================] - 32s 10s/step - loss: 1113.2789 - val_loss: 42941.8867

# %%
model.predict('lion_tiger.jpg')
# Out:
# img shape:  (732, 1108, 3)
# 1/1 [==============================] - 1s 501ms/step
# # of bboxes: 0
# Empty DataFrame
# Columns: [x1, y1, x2, y2, class_name, score, w, h]
# Index: []
