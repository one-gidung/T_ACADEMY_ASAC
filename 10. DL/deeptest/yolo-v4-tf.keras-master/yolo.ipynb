# %% [markdown]
# 1. label 작업: labeling
# 2. 욜로 annotation.txt 이미지, 영역, 분류인덱스
# python xml_to_txt.

# %%
from models import Yolov4

# %%
model = Yolov4(weight_path='yolov4.weights',
             class_name_path='class_names/coco_classes.txt')
model.predict('street_view.jpg')
# Out:
# nms iou: 0.413 score: 0.3
# all weights read
# load from yolov4.weights
# img shape:  (667, 1000, 3)
# 1/1 [==============================] - 2s 2s/step
# # of bboxes: 17
#      x1   y1   x2   y2 class_name     score    w    h
# 0   649  378  707  576     person  0.996679   58  198
# 1    31  295  146  639     person  0.996260  115  344
# 2   125  339  245  645     person  0.996062  120  306
# 3   499  334  598  610     person  0.995808   99  276
# 4   715  387  792  621     person  0.993460   77  234
# 5   287  337  368  562     person  0.993160   81  225
# 6   584  359  651  592     person  0.987191   67  233
# 7   359  330  432  556     person  0.986427   73  226
# 8   899  569  926  631        dog  0.947317   27   62
# 9   519  480  570  621    bicycle  0.940864   51  141
# 10  427  383  475  516     person  0.890076   48  133
# 11  297  436  360  582    bicycle  0.842618   63  146
# 12  457  373  493  508     person  0.753729   36  135
# 13  365  434  414  566    bicycle  0.746470   49  132
# 14  423  426  465  535    bicycle  0.695999   42  109
# 15  500  376  519  429     person  0.684849   19   53
# 16  705  368  761  490     person  0.539496   56  122

# %%
from utils import DataGenerator, read_annotation_lines
from models import Yolov4

# %%
train_lines, val_lines = read_annotation_lines('./dataset/txt/anno.txt', test_size=0.1)

FOLDER_PATH = './dataset/img'
class_name_path = './class_names/classes.txt'
data_gen_train = DataGenerator( train_lines, class_name_path, FOLDER_PATH )
data_gen_val = DataGenerator( val_lines, class_name_path, FOLDER_PATH )

# %%
model = Yolov4(class_name_path=class_name_path )
model.fit( data_gen_train, initial_epoch=0, epochs=10, val_data_gen=data_gen_val )
# Out:
# nms iou: 0.413 score: 0.3
# Epoch 1/10
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 23/23 [==============================] - 338s 13s/step - loss: 30027.5996 - val_loss: nan
# Epoch 2/10
# 23/23 [==============================] - 300s 13s/step - loss: 861.3984 - val_loss: 23154.9180
# Epoch 3/10
# 23/23 [==============================] - 449s 20s/step - loss: 408.6566 - val_loss: 10495.1055
# Epoch 4/10
# 23/23 [==============================] - 418s 18s/step - loss: 319.5453 - val_loss: 5586.8354
# Epoch 5/10
# 23/23 [==============================] - 419s 19s/step - loss: 277.7375 - val_loss: 2910.5002
# Epoch 6/10
# 23/23 [==============================] - 709s 31s/step - loss: 255.7049 - val_loss: 1811.0664
# Epoch 7/10
# 23/23 [==============================] - 652s 28s/step - loss: 226.1635 - val_loss: 1097.9781
# Epoch 8/10
# 23/23 [==============================] - 359s 15s/step - loss: 210.7852 - val_loss: 787.3188
# Epoch 9/10
# 23/23 [==============================] - 354s 15s/step - loss: 196.0332 - val_loss: 603.5795
# Epoch 10/10
# 23/23 [==============================] - 350s 15s/step - loss: 184.5115 - val_loss: 463.0497
