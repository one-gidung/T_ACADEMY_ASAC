# %%
# api를 통해서 원하는 데이터를 받으려고 함
# 양식 : XML

# %%
# 필요한 패키지
import pandas as pd
# 통신 관련
import urllib.request
# xml, html tag 중심의 언어 처리...
from bs4 import BeautifulSoup

# %%
# 영화 목록 요청 url을 완성
key = "edef7c61e5650b860807260fc96f9504"
base_url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.xml"
show_num = 40
url = base_url + "?key=" + key + "&itemPerPage" + str(show_num)
url
# Out:
# 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.xml?key=edef7c61e5650b860807260fc96f9504&itemPerPage40'

# %%
# 이 영화 목록 요청하는 주소를 직접 pi에 요청하자.. urllib
res = urllib.request.urlopen(url)
# xml 을 보다 쉽게 찾거나 접근하기 위한 패키지 : beautifulsoup
soup = BeautifulSoup(res, "html.parser")
# Out:
# C:\Users\NTX550\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
print(soup.prettify())
# 전부 소문자로 converting된다!!!!
# 치명적인 단점
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="yes"?>
# <movielistresult>
#  <totcnt>
#   92583
#  </totcnt>
#  <movielist>
#   <movie>
#    <moviecd>
#     20217624
#    </moviecd>
#    <movienm>
#     컴백홈
#    </movienm>
#    <movienmen>
#     Come Back Home
#    </movienmen>
#    <prdtyear>
#     2022
#    </prdtyear>
#    <opendt>
#     20221005
#    </opendt>
#    <typenm>
#     장편
#    </typenm>
#    <prdtstatnm>
#     개봉
#    </prdtstatnm>
#    <nationalt>
#     한국
#    </nationalt>
#    <genrealt>
#     드라마,코미디
#    </genrealt>
#    <repnationnm>
#     한국
#    </repnationnm>
#    <repgenrenm>
#     드라마
#    </repgenrenm>
#    <directors>
#     <director>
#      <peoplenm>
#       이연우
#      </peoplenm>
#     </director>
#    </directors>
#    <companys>
#     <company>
#      <companycd>
#       20205261
#      </companycd>
#      <companynm>
#       (주)슬기로운늑대
#      </companynm>
#     </company>
#     <company>
#      <companycd>
#       20142369
#      </companycd>
#      <companynm>
#       (유)조이앤시네마
#      </companynm>
#     </company>
#    </companys>
#   </movie>
#   <movie>
#    <moviecd>
#     20211566
#    </moviecd>
#    <movienm>
#     낮과 달
#    </movienm>
#    <movienmen>
#     The Cave
#    </movienmen>
#    <prdtyear>
#     2021
#    </prdtyear>
#    <opendt>
#     20221020
#    </opendt>
#    <typenm>
#     장편
#    </typenm>
#    <prdtstatnm>
#     개봉
#    </prdtstatnm>
#    <nationalt>
#     한국
#    </nationalt>
#    <genrealt>
#     드라마
#    </genrealt>
#    <repnationnm>
#     한국
#    </repnationnm>
#    <repgenrenm>
#     드라마
#    </repgenrenm>
#    <directors>
#     <director>
#      <peoplenm>
#       이영아
#      </peoplenm>
#     </director>
#    </directors>
#    <companys>
#     <company>
#      <companycd>
#       20100572
#      </companycd>
#      <companynm>
#       한국영화아카데미
#      </companynm>
#     </company>
#    </companys>
#   </movie>
#   <movie>
#    <moviecd>
#     20223740
#    </moviecd>
#    <movienm>
#     크리스마스 캐럴
#    </movienm>
#    <movienmen>
#     christmas carol
#    </movienmen>
#    <prdtyear>
#     2022
#    </prdtyear>
#    <opendt>
#    </opendt>
#    <typenm>
#     장편
#    </typenm>
#    <prdtstatnm>
#     개봉준비
#    </prdtstatnm>
#    <nationalt>
#     한국
#    </nationalt>
#    <genrealt>
#     드라마,액션
#    </genrealt>
#    <repnationnm>
#     한국
#    </repnationnm>
#    <repgenrenm>
#     드라마
#    </repgenrenm>
#    <directors>
#     <director>
#      <peoplenm>
#       김성수
#      </peoplenm>
#     </director>
#    </directors>
#    <companys>
#     <company>
#      <companycd>
#       20100851
#      </companycd>
#      <companynm>
#       (주)화인컷
#      </companynm>
#     </company>
#    </companys>
#   </movie>
#   <movie>
#    <moviecd>
#     20227751
#    </moviecd>
#    <movienm>
#     가재가 노래하는 곳
#    </movienm>
#    <movienmen>
#     Where the Crawdads Sing
#    </movienmen>
#    <prdtyear>
#     2021
#    </prdtyear>
#    <opendt>
#     20221102
#    </opendt>
#    <typenm>
#     장편
#    </typenm>
#    <prdtstatnm>
#     개봉예정
#    </prdtstatnm>
#    <nationalt>
#     미국
#    </nationalt>
#    <genrealt>
#     드라마
#    </genrealt>
#    <repnationnm>
#     미국
#    </repnationnm>
#    <repgenrenm>
#     드라마
#    </repgenrenm>
#    <directors>
#     <director>
#      <peoplenm>
#       올리비아 뉴먼
#      </peoplenm>
#     </director>
#    </directors>
#    <companys>
#    </companys>
#   </movie>
#   <movie>
#    <moviecd>
#     20192206
#    </moviecd>
#    <movienm>
#     백두산
#    </movienm>
#    <movienmen>
#     ASHFALL
#    </movienmen>
#    <prdtyear>
#     2019
#    </prdtyear>
#    <opendt>
#     20191219
#    </opendt>
#    <typenm>
#     장편
#    </typenm>
#    <prdtstatnm>
#     개봉
#    </prdtstatnm>
#    <nationalt>
#     한국
#    </nationalt>
#    <genrealt>
#     어드벤처,드라마
#    </genrealt>
#    <repnationnm>
#     한국
#    </repnationnm>
#    <repgenrenm>
#     어드벤처
#    </repgenrenm>
#    <directors>
#     <director>
#      <peoplenm>
#       이해준
#      </peoplenm>
#     </director>
#     <director>
#      <peoplenm>
#       김병서
#      </peoplenm>
#     </director>
#    </directors>
#    <companys>
#     <company>
#      <companycd>
#       20192641
#      </companycd>
#      <companynm>
#       주식회사 덱스터 픽쳐스
#      </companynm>
#     </company>
#     <company>
#      <companycd>
#       20140593
#      </companycd>
#      <companynm>
#       (주)퍼펙트스톰필름
#      </companynm>
#     </company>
#     <company>
#      <companycd>
#       20110854
#      </companycd>
#      <companynm>
#       (주)씨제이이엔엠
#      </companynm>
#     </company>
#    </companys>
#   </movie>
#   <movie>
#    <moviecd>
#     20227756
#    </moviecd>
#    <movienm>
#     킹덤2: 아득한 대지로
#    </movienm>
#    <movienmen>
#     Kingdom2
#    </movienmen>
#    <prdtyear>
#     2022
#    </prdtyear>
#    <opendt>
#     20221116
#    </opendt>
#    <typenm>
#     장편
#    </typenm>
#    <prdtstatnm>
#     개봉예정
#    </prdtstatnm>
#    <nationalt>
#     미국
#    </nationalt>
#    <genrealt>
#     액션,전쟁
#    </genrealt>
#    <repnationnm>
#     미국
#    </repnationnm>
#    <repgenrenm>
#     액션
#    </repgenrenm>
#    <directors>
#     <director>
#      <peoplenm>
#       사토 신스케
#      </peoplenm>
#     </director>
#    </directors>
#    <companys>
#    </companys>
#   </movie>
#   <movie>
#    <moviecd>
#     20227728
#    </moviecd>
#    <movienm>
#     극장판 유루캠△
#    </movienm>
#    <movienmen>
#     LAID-BACK CAMP THE MOVIE
#    </movienmen>
#    <prdtyear>
#     2022
#    </prdtyear>
#    <opendt>
#    </opendt>
#    <typenm>
#     장편
#    </typenm>
#    <prdtstatnm>
#     개봉예정
#    </prdtstatnm>
#    <nationalt>
#     일본
#    </nationalt>
#    <genrealt>
#     애니메이션,드라마
#    </genrealt>
#    <repnationnm>
#     일본
#    </repnationnm>
#    <repgenrenm>
#     애니메이션
#    </repgenrenm>
#    <directors>
#    </directors>
#    <companys>
#    </companys>
#   </movie>
#   <movie>
#    <moviecd>
#     20211242
#    </moviecd>
#    <movienm>
#     고속도로 가족
#    </movienm>
#    <movienmen>
#     Highway Family
#    </movienmen>
#    <prdtyear>
#     2022
#    </prdtyear>
#    <opendt>
#     20221102
#    </opendt>
#    <typenm>
#     장편
#    </typenm>
#    <prdtstatnm>
#     개봉예정
#    </prdtstatnm>
#    <nationalt>
#     한국
#    </nationalt>
#    <genrealt>
#     드라마
#    </genrealt>
#    <repnationnm>
#     한국
#    </repnationnm>
#    <repgenrenm>
#     드라마
#    </repgenrenm>
#    <directors>
#     <director>
#      <peoplenm>
#       이상문
#      </peoplenm>
#     </director>
#    </directors>
#    <companys>
#     <company>
#      <companycd>
#       20203424
#      </companycd>
#      <companynm>
#       (주)영화사 설렘
#      </companynm>
#     </company>
#     <company>
#      <companycd>
#       20217743
#      </companycd>
#      <companynm>
#       (주)고고스튜디오
#      </companynm>
#     </company>
#    </companys>
#   </movie>
#   <movie>
#    <moviecd>
#     20228105
#    </moviecd>
#    <movienm>
#     프레스 플레이
#    </movienm>
#    <movienmen>
#     Press Play
#    </movienmen>
#    <prdtyear>
#     2021
#    </prdtyear>
#    <opendt>
#     20221025
#    </opendt>
#    <typenm>
#     장편
#    </typenm>
#    <prdtstatnm>
#     개봉
#    </prdtstatnm>
#    <nationalt>
#     미국
#    </nationalt>
#    <genrealt>
#     멜로/로맨스,드라마,판타지
#    </genrealt>
#    <repnationnm>
#     미국
#    </repnationnm>
#    <repgenrenm>
#     멜로/로맨스
#    </repgenrenm>
#    <directors>
#     <director>
#      <peoplenm>
#       그렉 비요크만
#      </peoplenm>
#     </director>
#    </directors>
#    <companys>
#     <company>
#      <companycd>
#       20110854
#      </companycd>
#      <companynm>
#       (주)씨제이이엔엠
#      </companynm>
#     </company>
#    </companys>
#   </movie>
#   <movie>
#    <moviecd>
#     20228062
#    </moviecd>
#    <movienm>
#     살인청부업자
#    </movienm>
#    <movienmen>
#     HIT MAN
#    </movienmen>
#    <prdtyear>
#     2022
#    </prdtyear>
#    <opendt>
#    </opendt>
#    <typenm>
#     장편
#    </typenm>
#    <prdtstatnm>
#     개봉예정
#    </prdtstatnm>
#    <nationalt>
#     한국
#    </nationalt>
#    <genrealt>
#     범죄,스릴러
#    </genrealt>
#    <repnationnm>
#     한국
#    </repnationnm>
#    <repgenrenm>
#     범죄
#    </repgenrenm>
#    <directors>
#     <director>
#      <peoplenm>
#       강태호
#      </peoplenm>
#     </director>
#    </directors>
#    <companys>
#     <company>
#      <companycd>
#       20063058
#      </companycd>
#      <companynm>
#       (주)피터팬픽쳐스
#      </companynm>
#     </company>
#    </companys>
#   </movie>
#  </movielist>
#  <source/>
#  영화진흥위원회
# </movielistresult>

# %%
# 내가 원하는 정보가 어느 태그로 있는지 파악
# 찾는 것도 tag중심으로
# 1) find; 전체 태그들 중에서 내가 찾고자 하는 태그하고 매칭 중 처음 값!
# 2) find_all : 해당하는 태그들을 싹 다 찿ㅈ아서 --<

# %%
soup.find('movie')
# Out:
# <movie><moviecd>20217624</moviecd><movienm>컴백홈</movienm><movienmen>Come Back Home</movienmen><prdtyear>2022</prdtyear><opendt>20221005</opendt><typenm>장편</typenm><prdtstatnm>개봉</prdtstatnm><nationalt>한국</nationalt><genrealt>드라마,코미디</genrealt><repnationnm>한국</repnationnm><repgenrenm>드라마</repgenrenm><directors><director><peoplenm>이연우</peoplenm></director></directors><companys><company><companycd>20205261</companycd><companynm>(주)슬기로운늑대</companynm></company><company><companycd>20142369</companycd><companynm>(유)조이앤시네마</companynm></company></companys></movie>

# %%
soup.find_all('movie')[0]
# Out:
# <movie><moviecd>20217624</moviecd><movienm>컴백홈</movienm><movienmen>Come Back Home</movienmen><prdtyear>2022</prdtyear><opendt>20221005</opendt><typenm>장편</typenm><prdtstatnm>개봉</prdtstatnm><nationalt>한국</nationalt><genrealt>드라마,코미디</genrealt><repnationnm>한국</repnationnm><repgenrenm>드라마</repgenrenm><directors><director><peoplenm>이연우</peoplenm></director></directors><companys><company><companycd>20205261</companycd><companynm>(주)슬기로운늑대</companynm></company><company><companycd>20142369</companycd><companynm>(유)조이앤시네마</companynm></company></companys></movie>
