# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/소상공인시장진흥공단_상가(상권)정보_서울_202206.csv')
df.head()
# Out:
#      상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0  23324279       제중건강원  NaN         D       소매       D10    건강/미용식품
# 1  24525909       민속악기사  NaN         D       소매       D04  취미/오락관련소매
# 2  24715368       태평양진주  NaN         D       소매       D26   시계/귀금속소매
# 3  15554136  김선희꼼꼼국어교습소  NaN         R    학문/교육       R01  학원-보습교습입시
# 4  17174175         비지트  NaN         Q       음식       Q01         한식
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호     건물명  \
# 0    D10A07        건강원   G47216  ...  1156010600100410002034626     NaN
# 1    D04A09       악기판매   G47593  ...  1120012200101420011000227     NaN
# 2    D26A01     시계/귀금속   G47830  ...  1111015200100440000000001  금사랑투빌딩
# 3    R01A01      학원-입시   P85501  ...  1171011100101970003017195     NaN
# 4    Q01A01  한식/백반/한정식   I56111  ...  1165010100108540018009586   상랑의빌딩
#
#                      도로명주소   구우편번호   신우편번호  동정보  층정보  호정보          경도  \
# 0  서울특별시 영등포구 영중로14길 11-17  150035  7250.0  NaN    1  NaN  126.907168
# 1         서울특별시 성동구 용답5길 2  133849  4803.0  NaN  NaN  NaN  127.049018
# 2     서울특별시 종로구 서순라길 17-10  110390  3138.0  NaN  NaN  NaN  126.993530
# 3    서울특별시 송파구 위례성대로12길 31  138834  5640.0  NaN    2  NaN  127.121520
# 4      서울특별시 서초구 동광로18길 82  137837  6572.0  NaN    1  NaN  126.991394
#
#           위도
# 0  37.520613
# 1  37.566857
# 2  37.571848
# 3  37.510967
# 4  37.488375
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df = df.loc[:,['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '도로명', '시군구명', '행정동명']]
df
# Out:
#                      상호명 상권업종대분류명   상권업종중분류명   상권업종소분류명                 도로명  \
# 0                  제중건강원       소매    건강/미용식품        건강원   서울특별시 영등포구 영중로14길
# 1                  민속악기사       소매  취미/오락관련소매       악기판매      서울특별시 성동구 용답5길
# 2                  태평양진주       소매   시계/귀금속소매     시계/귀금속      서울특별시 종로구 서순라길
# 3             김선희꼼꼼국어교습소    학문/교육  학원-보습교습입시      학원-입시  서울특별시 송파구 위례성대로12길
# 4                    비지트       음식         한식  한식/백반/한정식    서울특별시 서초구 동광로18길
# ...                  ...      ...        ...        ...                 ...
# 346224  신내역시티부동산공인중개사사무소      부동산      부동산중개      부동산중개   서울특별시 중랑구 봉화산로59길
# 346225             석정칼국수       음식         분식  국수/만두/칼국수       서울특별시 중랑구 면목로
# 346226          서울왕도숯불갈비       음식         한식  한식/백반/한정식     서울특별시 동대문구 약령시로
# 346227                칠교    생활서비스     기타서비스업     사업경영상담       서울특별시 금천구 범안로
# 346228        마음공감심리상담센터       소매  선물/팬시/기념품     꽃집/꽃배달   서울특별시 영등포구 선유로13길
#
#         시군구명         행정동명
# 0       영등포구         영등포동
# 1        성동구          용답동
# 2        종로구  종로1.2.3.4가동
# 3        송파구         방이1동
# 4        서초구         방배4동
# ...      ...          ...
# 346224   중랑구         망우본동
# 346225   중랑구         면목본동
# 346226  동대문구          제기동
# 346227   금천구          가산동
# 346228  영등포구          문래동
#
# [346229 rows x 7 columns]

# %%
df = df[df['시군구명'] == '강남구']
df = df[df['상권업종대분류명'] == '음식']
df = df.reset_index(drop=True)
df
# Out:
#                 상호명 상권업종대분류명 상권업종중분류명     상권업종소분류명                도로명 시군구명  \
# 0            고향생막걸리       음식     유흥주점         민속주점     서울특별시 강남구 압구정로  강남구
# 1           의정부부대찌개       음식       한식    부대찌개/섞어찌개   서울특별시 강남구 역삼로83길  강남구
# 2              바른치킨       음식   닭/오리요리    후라이드/양념치킨   서울특별시 강남구 선릉로86길  강남구
# 3               알뤼르       음식   커피점/카페  커피전문점/카페/다방   서울특별시 강남구 삼성로85길  강남구
# 4                하레       음식     유흥주점        로바다야끼  서울특별시 강남구 영동대로85길  강남구
# ...             ...      ...      ...          ...                ...  ...
# 11426   육회왕자연어공주코엑스       음식       한식    한식/백반/한정식   서울특별시 강남구 삼성로96길  강남구
# 11427         밸런스포케       음식       양식     정통양식/경양식  서울특별시 강남구 강남대로94길  강남구
# 11428         덕수파스타       음식       양식      스파게티전문점     서울특별시 강남구 봉은사로  강남구
# 11429  타이니커피브루잉스튜디오       음식   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 도산대로89길  강남구
# 11430         헬시플레저       음식    패스트푸드         피자전문  서울특별시 강남구 논현로102길  강남구
#
#        행정동명
# 0      압구정동
# 1      대치2동
# 2      대치4동
# 3      대치4동
# 4      대치2동
# ...     ...
# 11426  삼성1동
# 11427  역삼1동
# 11428  삼성2동
# 11429   청담동
# 11430  역삼1동
#
# [11431 rows x 7 columns]

# %%
# 상호명, 행정동명
df['검색어'] = df['행정동명'] + " " + df['상호명']
df['검색어']
# Out:
# 0             압구정동 고향생막걸리
# 1            대치2동 의정부부대찌개
# 2               대치4동 바른치킨
# 3                대치4동 알뤼르
# 4                 대치2동 하레
#                ...
# 11426    삼성1동 육회왕자연어공주코엑스
# 11427          역삼1동 밸런스포케
# 11428          삼성2동 덕수파스타
# 11429    청담동 타이니커피브루잉스튜디오
# 11430          역삼1동 헬시플레저
# Name: 검색어, Length: 11431, dtype: object

# %%
import re
import os
from time import sleep

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from bs4 import BeautifulSoup

##############################################################  ############
##################### variable related selenium ##########################
##########################################################################
options = webdriver.ChromeOptions()
# options.add_argument('headless')
options.add_argument('lang=ko_KR')
chromedriver_path = r"C:\Users\NTX550\Desktop\chromedriver.exe"
driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)  # chromedriver 열기


def main():
    global driver, load_wb, review_num

    driver.implicitly_wait(4)  # 렌더링 될때까지 기다린다 4초
    driver.get('https://map.kakao.com/')  # 주소 가져오기

    # 검색할 목록
    place_infos = ['강남 맛집']

    for i, place in enumerate(place_infos):
        # delay
        if i % 4 == 0 and i != 0:
            sleep(5)
        print("#####", i)
        search(place)

    driver.quit()
    print("finish")


def search(place):
    global driver

    search_area = driver.find_element(By.XPATH, '//*[@id="search.keyword.query"]')  # 검색 창
    search_area.send_keys(place)  # 검색어 입력
    driver.find_element(By.XPATH, '//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    sleep(1)

    # 검색된 정보가 있는 경우에만 탐색
    # 1번 페이지 place list 읽기
    html = driver.page_source

    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem') # 검색된 장소 목록

    # 검색된 첫 페이지 장소 목록 크롤링하기
    crawling(place, place_lists)
    search_area.clear()

    # 우선 더보기 클릭해서 2페이지
    try:
        driver.find_element(By.XPATH, '//*[@id="info.search.place.more"]').send_keys(Keys.ENTER)
        sleep(1)

        # 2~ 5페이지 읽기
        for i in range(2, 6):
            # 페이지 넘기기
            xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
            driver.find_element(By.XPATH, xPath).send_keys(Keys.ENTER)
            sleep(1)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            place_lists = soup.select('.placelist > .PlaceItem') # 장소 목록 list

            crawling(place, place_lists)

    except ElementNotInteractableException:
        print('not found')
    finally:
        search_area.clear()


def crawling(place, place_lists):
    """
    페이지 목록을 받아서 크롤링 하는 함수
    :param place: 리뷰 정보 찾을 장소이름
    """

    while_flag = False
    for i, place in enumerate(place_lists):
        # 광고에 따라서 index 조정해야함
        #if i >= 3:
         #   i += 1

        place_name = place.select('.head_item > .tit_name > .link_name')[0].text  # place name
        place_address = place.select('.info_item > .addr > p')[0].text  # place address

        detail_page_xpath = '//*[@id="info.search.place.list"]/li[' + str(i + 1) + ']/div[5]/div[4]/a[1]'
        driver.find_element(By.XPATH, detail_page_xpath).send_keys(Keys.ENTER)
        driver.switch_to.window(driver.window_handles[-1])  # 상세정보 탭으로 변환
        sleep(1)

        print('####', place_name)

        # 첫 페이지
        driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
        driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
        sleep(1)
        extract_review(place_name)

        # 2-5 페이지
        idx = 3
        try:
            page_num = len(driver.find_elements(By.CLASS_NAME, 'link_page')) # 페이지 수 찾기
            for i in range(page_num-1):
                # css selector를 이용해 페이지 버튼 누르기
                driver.find_element(By.CSS_SELECTOR, '#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
#                 sleep(1)
                driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
                driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
                sleep(1)
                extract_review(place_name)
                idx += 1
            driver.find_element(By.LINK_TEXT, '다음').send_keys(Keys.ENTER) # 5페이지가 넘는 경우 다음 버튼 누르기
#             sleep(1)
            driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
            driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
            sleep(1)
            extract_review(place_name) # 리뷰 추출
        except (NoSuchElementException, ElementNotInteractableException):
            print("no review in crawling")

        # 그 이후 페이지
        while True:
            idx = 4
            try:
                page_num = len(driver.find_elements(By.CLASS_NAME, 'link_page'))
                for i in range(page_num-1):
                    driver.find_element(By.CSS_SELECTOR, '#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
#                     sleep(1)
                    driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
                    driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
                    sleep(1)
                    extract_review(place_name)
                    idx += 1
                driver.find_element(By.LINK_TEXT, '다음').send_keys(Keys.ENTER) # 10페이지 이상으로 넘어가기 위한 다음 버튼 클릭
#                 sleep(1)
                driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
                driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
                sleep(1)
                extract_review(place_name) # 리뷰 추출
            except (NoSuchElementException, ElementNotInteractableException):
                print("no review in crawling")
                break

        driver.close()
        driver.switch_to.window(driver.window_handles[0])  # 검색 탭으로 전환


def extract_review(place_name):
    global driver

    ret = True

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 첫 페이지 리뷰 목록 찾기
    review_lists = soup.select('.list_evaluation > li')
    print(len(review_lists))

    # 리뷰가 있는 경우
    if len(review_lists) != 0:
        for i, review in enumerate(review_lists):
            comment = review.select('.txt_comment > span') # 리뷰
            rating = review.select('.star_info > div > span > span')[0]['style'] # 별점
            if len(comment) != 0:
                if len(rating) != 0:
                    val = comment[0].text + '/' + re.findall("\d+", rating)[0].replace('점', '')
                else:
                    val = comment[0].text + '/0'
                print(val)
            if i == 9: break

    else:
        print('no review in extract')
        ret = False

    return ret


if __name__ == "__main__":
    main()
# Out:
# C:\Users\NTX550\AppData\Local\Temp\ipykernel_22060\942804517.py:22: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)  # chromedriver 열기
# ##### 0
# #### 중앙해장
# 13
# /60
# 웨이팅한 시간이 아깝지 않은 맛/100
# 한번씩 먹을만한 곳..대기가 길지만 해장국에 건더기도 실하고 곰탕 고기도 넘 부드러웠어요/80
# 비싼데 맛있음 곱창이 확실히 좋음/100
# /80
# /20
# 대박/100
# /80
# 비싼데 맛있음 곱창이 확실히 좋음/100
# /80
# /20
# no review in crawling
# no review in crawling
# #### 진미평양냉면
# 13
# /80
# 서울 평양냉면 중에 거의 탑이라고 생각되는 미쉐린 평양냉면 맛집입니다. 연예인들의 맛집이기도 하고 평냉의 깔끔함, 제육의 깔끔한 기름의 조화가 술 맛으로 이끌기 아주 좋습니다./100
# /100
# 또 갈거양/100
# 아래 중국이나 북한 느낌이라는 후기있는데 정확합니다 여긴 조선족가게이니까..맛없는건 기본이죠/20
# 신흥. 정식당이 극찬깔끔. 어울리지는 않지만 수육도 굿/80
# 육수에 간이 강해서 살짝 놀랐다가 먹다보니 또 적응됨. 그날따라 내 혀에 무슨 일이 있었나 면 메밀향이랑 육수 육향이 잘 느껴지지 않아 괴로왔는데 냉면 안에 편육 두 조각이 천국이었음; 육수는 뭔가 잘 모르겠음..ㅜ그치만 역시 내 마음 속 원픽은 역시 “필동”인 건가…필동>을밀대/을지>…. 우래옥.. 그 다음 진미..후… 필동 마렵다…너무 시끄러워서 다시 가지는 않을듯/40
# 냉면 먹고싶을 때마다 항상 가는 곳./100
# 또 갈거양/100
# 아래 중국이나 북한 느낌이라는 후기있는데 정확합니다 여긴 조선족가게이니까..맛없는건 기본이죠/20
# 신흥. 정식당이 극찬깔끔. 어울리지는 않지만 수육도 굿/80
# no review in crawling
# no review in crawling
# #### 노티드 청담
# 13
# 우유생크림도넛 기본인데 진짜 제일 맛있음/80
# 별점4.2점 우유크림도넛.스트로베리크림도넛맛있다~~~~/80
# 우유 크림 맛있지만 도넛은 도넛일뿐. 직원들은 친절한 편 위생에 신경써야 할 듯/60
# 노티드는 사랑입니다./100
# 인스타에서 많이 봤었는데 역시 사람이 많네요 맛있어요!/100
# 사람이 많아서 대기는 좀 있지만 디저트 맛있어요/80
# 믿고가는노티드/100
# /100
# 노티드는 사랑입니다./100
# 인스타에서 많이 봤었는데 역시 사람이 많네요 맛있어요!/100
# 사람이 많아서 대기는 좀 있지만 디저트 맛있어요/80
# no review in crawling
# no review in crawling
# #### 꽁티드툴레아 도산점
# 13
# /80
# /60
# 웨이팅이 너무 긴데 밖에 서서 기다려야해요 ㅠㅠ 게다가 식당 내부도 너무 춥고 음식 하나 나오고 거의 다 먹을때쯤 다른거 나와서 넘 아쉽습니다 ㅜㅜ 웨이팅 한시간 해서 먹을 맛은 아닌 것 같고 예약 가능하면 다른 메뉴 맛보러 갈 순 있을 것 같아용/60
# 분위기야 말모..웨이팅때문에 자주는 못갈듯해여/80
# /100
# 분위기는 좋은데 맛은 잘 모르겠어요!청담에서 가성비는 못 따지고 ㅠ 야외 앉으려면 오래 기다려야되요/40
# 양이적고 비싼데 맛은있음!분위기도 있음가끔 갈만함 ㅎ/60
# 진짜 킹받아요,, 휴대폰 충전 된다해서 맡겼는데 찾으러가니 안 꽂아두셨더라구요? 지금보니 10퍼 그대로임40분동안 폰 왜 맡긴걸까요,,? 초코무스 맛있으면 뭐함 와인 맛있으면 뭐함 9퍼 되어가지고 겨우 택시불러 갑니다 카운터에 있던 여자분 ㅠ 짱나요 진짜 7퍼 됐지만 열받아서 리뷰 써요/60
# 분위기야 말모..웨이팅때문에 자주는 못갈듯해여/80
# /100
# 분위기는 좋은데 맛은 잘 모르겠어요!청담에서 가성비는 못 따지고 ㅠ 야외 앉으려면 오래 기다려야되요/40
# no review in crawling
# no review in crawling
# #### 스케줄 청담
# 13
# 5월, 6월 리뷰 냄새가 킁킁...저는 회사 근처라 가끔 갔는데 생~각보다 맛은 있고 생~각보다 불친절하지 않았어요ㅋㅋㅋ/40
# 그냥 저냥...지인이 여기로 약속잡으면 어쩔수없이 가는 곳..옛날 오늘있던 자리. 가게는 예쁜데 가게를 채운 사람들이 너무 좀 별로임 직원들은 매너있고 친절하심/40
# 여기가 유튜브에 나온 그 유명한 문신돼지들 정모 장소입니까?ㅋㅋㅋㅋㅋㅋㅋ 맛이  궁금하군요/100
# 가성비 제로/20
# 진짜 드럽게 맛 없고 쳐비싸기만함/20
# /60
# 김볶 맛있어용/60
# 최악 맛 1/5 서비스 2/5가격 1/5분위기 3/5 위생 2/5/20
# 가성비 제로/20
# 진짜 드럽게 맛 없고 쳐비싸기만함/20
# /60
# no review in crawling
# no review in crawling
# #### 팀호완 삼성점
# 13
# 작년에는 맛있었는데,, 이번엔그닥…./40
# 킹갓 팀호완 인정... 넘나 맛있는 것... 양이 적을수도있지만 맛이 아주.../100
# 맛잇는데 비싸고 양적어요 웨이팅 장난아님. 예약꼭하세요/80
# 두유피 새우춘권, 닭고기 덮밥, 부채교, 홍콩식 우육면, 차슈바오 번이 중 홍콩식 우육면과 차슈바오 번은 괜찮고 나머진 그냥저냥. 닭고기 덮밥은 한입 먹고 후회.메뉴마다 양이 적고 조금조금씩 나옴./60
# 확실히 맛남. 딘타이펑보다 한국화가 덜되고 좋음ㅎ 무떡이랑 완탕비빔면 전복샤오마이 맛있게 잘 먹음/100
# /80
# 홍콩 언제 갈 수 있지 ㅜ ㅜ/80
# 타이페이에서 처음 접한 틴호완의 감동을 돌려줘/60
# 두유피 새우춘권, 닭고기 덮밥, 부채교, 홍콩식 우육면, 차슈바오 번이 중 홍콩식 우육면과 차슈바오 번은 괜찮고 나머진 그냥저냥. 닭고기 덮밥은 한입 먹고 후회.메뉴마다 양이 적고 조금조금씩 나옴./60
# 확실히 맛남. 딘타이펑보다 한국화가 덜되고 좋음ㅎ 무떡이랑 완탕비빔면 전복샤오마이 맛있게 잘 먹음/100
# /80
# no review in crawling
# no review in crawling
# #### 뽕나무쟁이 선릉본점
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22060\942804517.py in <module>
#     196
#     197 if __name__ == "__main__":
# --> 198     main()
#
# ~\AppData\Local\Temp\ipykernel_22060\942804517.py in main()
#      37             sleep(5)
#      38         print("#####", i)
# ---> 39         search(place)
#      40
#      41     driver.quit()
#
# ~\AppData\Local\Temp\ipykernel_22060\942804517.py in search(place)
#      59
#      60     # 검색된 첫 페이지 장소 목록 크롤링하기
# ---> 61     crawling(place, place_lists)
#      62     search_area.clear()
#      63
#
# ~\AppData\Local\Temp\ipykernel_22060\942804517.py in crawling(place, place_lists)
#     111         driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
#     112         driver.find_element(By.LINK_TEXT, '후기 더보기').send_keys(Keys.ENTER)
# --> 113         sleep(1)
#     114         extract_review(place_name)
#     115
#
# KeyboardInterrupt:

# %%
def extract_review(place_name):
    global driver

    ret = True

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 첫 페이지 리뷰 목록 찾기
    review_lists = soup.select('.list_evaluation > li')
    print(len(review_lists))

    # 리뷰가 있는 경우
    if len(review_lists) != 0:
        
        temp_r = list()
        temp_s = 0
        for i, review in enumerate(review_lists):
            
            tamp_r += review.select('.txt_comment > span')
            temp_s += int(review.select('.star_info > div > span > span')[0]['style'])
            
            
            if i == 9: break
        temp_s /= 10

    else:
        print('no review in extract')
        ret = False

    return ret

# %%
main=pd.concat(tot_list)
